# %% [markdown]
# # Uji Kemahiran Qiskit Anda!

# %% [markdown]
# ## Ringkasan
#
# Ini adalah ujian singkat untuk kemampuan Qiskit tingkat dasar Anda.

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### Kuis cepat
#
# <!-- ::: q-quiz(goal="qiskit-beginner-0") -->
#
# <!-- ::: .question -->
#
# Anda pikir Anda tahu Qiskit?
#
# <!-- ::: -->
#
# <!-- ::: .option(correct) -->
#
# 1. Ya -- Ayoo mulaiiii!
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# 1. Tidak yakin. Tapi izinkan saya mencobanya!
#
# <!-- ::: -->
#
# <!-- ::: -->

# %% [markdown]
# ## Soal 1
#
# Bangun sirkuit untuk status logo Qiskit yang ditunjukkan oleh Qsphere berikut:
#
# <img src="data:image/png;base64,...">

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
# from qiskit.visualization import plot_state_qsphere

num_qubits = 4

qreg_q = QuantumRegister(num_qubits, 'q')
creg_c = ClassicalRegister(num_qubits, 'c')
circuit = QuantumCircuit(num_qubits, num_qubits)

####### buat kode Anda di bawah ######### 





####### buat kode Anda di atas #########


# display(plot_state_qsphere(circuit))
display(circuit.draw('mpl'))


#grade_qiskitlogo(circuit) # Jenis hasil yang diharapkan:  QuantumCircuit

# %% [markdown]
# <!-- ::: q-block.reminder -->
#
# ### Petunjuk
#
# <details>     <summary>Petunjuk</summary>     Tweak sirkuit sampai Qsphere yang sesuai dengan sirkuit Anda cocok dengan Qsphere yang diberikan. </details>
#
# <!-- ::: -->
