# %% [markdown]
# # Lab 2 Single Qubit Gates
#
# Prerequisite
# [Ch.1.3 Representing Qubit States](/course/ch-states/representing-qubit-states)
# [Ch.1.4 Single Qubit Gates](/course/ch-states/single-qubit-gates)
#
# Other relevant materials
# [Grokking the Bloch Sphere](https://javafxpert.github.io/grok-bloch/)

# %%
import numpy as np

# Importing standard Qiskit libraries
from qiskit import QuantumCircuit, transpile, Aer, IBMQ, execute
from qiskit.tools.jupyter import *
from qiskit.visualization import *
from ibm_quantum_widgets import *
from qiskit.providers.aer import QasmSimulator

# Loading your IBM Quantum account(s)
provider = IBMQ.load_account()
backend = Aer.get_backend('statevector_simulator')

# %% [markdown]
# <h2 style="font-size:24px;">Part 1 - Effect of Single-Qubit Gates on state |0></h2>
#
# <br>
# <div style="background: #E8E7EB; border-radius: 5px;
# -moz-border-radius: 5px;">
#   <p style="background: #800080;
#             border-radius: 5px 5px 0px 0px;
#             padding: 10px 0px 10px 10px;
#             font-size:18px;
#             color:white;
#             "><b>Goal</b></p>
#     <p style=" padding: 0px 0px 10px 10px;
#               font-size:16px;">Create quantum circuits to apply various single qubit gates on state |0> and understand the change in state and phase of the qubit.</p>
# </div>

# %% [markdown]
# |![X gate applied to 0 state](images/L2_Xon0_circuit.png) | ![Y gate applied to 0 state](images/L2_Yon0_circuit.png)|![Z gate applied to 0 state](images/L2_Zon0_circuit.png) | ![S gate applied to 0 state](images/L2_Son0_circuit.png)|
# |-|-|-|-|
#
# To see the effect of each of the gates, we will take a single circuit with 4 qubits and apply a different gate to each of the qubits to plot the values of each of those qubits on the blocsphere.

# %%
qc1 = QuantumCircuit(4)

# perform gate operations on individual qubits
qc1.x(0)
qc1.y(1)
qc1.z(2)
qc1.s(3)

# Draw circuit
qc1.draw()

# %%
# Plot blochshere
out1 = execute(qc1,backend).result().get_statevector()
plot_bloch_multivector(out1)
# Out:
# /opt/conda/lib/python3.8/site-packages/qiskit/visualization/bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %% [markdown]
# |Effect on Qubit on application of Gate|Satevector|QSphere Plot|Statevector (Post Measurement)|
# |-|-|-|-|
# |Input State = $\begin{pmatrix}1+0j & 0+0j\end{pmatrix}$<br><br>Before measurement,<br>- qubit state = $\begin{pmatrix}0+0j & 1+0j\end{pmatrix}$<br>- qubit has probability 1 of being in state ‘1’<br><br>Post measurement, quit state is ‘1’ with phase 0 |![alt](images/L2_Xon0_statevector.png) | ![alt](images/L2_Xon0_qsphere.png)|![alt](images/L2_Xon0_statevector_postmeasurement.png) |
# |Input State = $\begin{pmatrix}1+0j & 0+0j\end{pmatrix}$<br><br>Before measurement,<br>- qubit state = $\begin{pmatrix}0+0j & 0+1j\end{pmatrix}$<br>- qubit has probability 1 of being in state ‘1’<br><br>Post measurement, quit state is ‘1’ with phase pi/2 |![alt](images/L2_Yon0_statevector.png) | ![alt](images/L2_Yon0_qsphere.png)|![alt](images/L2_Yon0_statevector_postmeasurement.png) |
# |Input State = $\begin{pmatrix}1+0j & 0+0j\end{pmatrix}$<br><br>Before measurement,<br>- qubit state = $\begin{pmatrix}1+0j & 0+0j\end{pmatrix}$<br>- qubit has probability 1 of being in state ‘0’<br><br>Post measurement, quit state is ‘0’ with phase 0 |![alt](images/L2_Zon0_statevector.png) | ![alt](images/L2_Zon0_qsphere.png)|![alt](images/L2_Zon0_statevector_postmeasurement.png) |
# |Input State = $\begin{pmatrix}1+0j & 0+0j\end{pmatrix}$<br><br>Before measurement,<br>- qubit state = $\begin{pmatrix}1+0j & 0+0j\end{pmatrix}$<br>- qubit has probability 1 of being in state ‘0’<br><br>Post measurement, quit state is ‘0’ with phase 0 |![alt](images/L2_Son0_statevector.png) | ![alt](images/L2_Son0_qsphere.png)|![alt](images/L2_Son0_statevector_postmeasurement.png) |

# %% [markdown]
# <h2 style="font-size:24px;">Part 2 - Effect of Single-Qubit Gates on state |1></h2>
#
# <br>
# <div style="background: #E8E7EB; border-radius: 5px;
# -moz-border-radius: 5px;">
#   <p style="background: #800080;
#             border-radius: 5px 5px 0px 0px;
#             padding: 10px 0px 10px 10px;
#             font-size:18px;
#             color:white;
#             "><b>Goal</b></p>
#     <p style=" padding: 0px 0px 10px 10px;
#               font-size:16px;">Create quantum circuits to apply various single qubit gates on state |1> and understand the change in state and phase of the qubit.</p>
# </div>

# %% [markdown]
# |![X gate applied to 1 state](images/L2_Xon1_circuit.png) | ![Y gate applied to 1 state](images/L2_Yon1_circuit.png)|![Z gate applied to 1 state](images/L2_Zon1_circuit.png) | ![S gate applied to 1 state](images/L2_Son1_circuit.png)|
# |-|-|-|-|
#
# To see the effect of each of the gates, we will take a single circuit with 4 qubits and apply a different gate to each of the qubits to plot the values of each of those qubits on the blocsphere.

# %%
qc2 = QuantumCircuit(4)

# initialize qubits
qc2.x(range(4))

# perform gate operations on individual qubits
qc2.x(0)
qc2.y(1)
qc2.z(2)
qc2.s(3)

# Draw circuit
qc2.draw()

# %%
# Plot blochshere
out2 = execute(qc2,backend).result().get_statevector()
plot_bloch_multivector(out2)

# %% [markdown]
# |Effect on Qubit on application of Gate|Satevector|QSphere Plot|Statevector (Post Measurement)|
# |-|-|-|-|
# |Input State = $\begin{pmatrix}0+0j & 1+0j\end{pmatrix}$<br><br>Before measurement,<br>- qubit state = $\begin{pmatrix}1+0j & 0+0j\end{pmatrix}$<br>- qubit has probability 1 of being in state ‘0’<br><br>Post measurement, quit state is ‘0’ with phase 0 |![alt](images/L2_Xon1_statevector.png) | ![alt](images/L2_Xon1_qsphere.png)|![alt](images/L2_Xon1_statevector_postmeasurement.png) |
# |Input State = $\begin{pmatrix}0+0j & 1+0j\end{pmatrix}$<br><br>Before measurement,<br>- qubit state = $\begin{pmatrix}0-1j & 0+0j\end{pmatrix}$<br>- qubit has probability 1 of being in state ‘0’<br><br>Post measurement, quit state is ‘0’ with phase 3pi/2 |![alt](images/L2_Yon1_statevector.png) | ![alt](images/L2_Yon1_qsphere.png)|![alt](images/L2_Yon1_statevector_postmeasurement.png) |
# |Input State = $\begin{pmatrix}0+0j & 1+0j\end{pmatrix}$<br><br>Before measurement,<br>- qubit state = $\begin{pmatrix}0+0j & -1+0j\end{pmatrix}$<br>- qubit has probability 1 of being in state ‘1’<br><br>Post measurement, quit state is ‘1’ with phase pi |![alt](images/L2_Zon1_statevector.png) | ![alt](images/L2_Zon1_qsphere.png)|![alt](images/L2_Zon1_statevector_postmeasurement.png) |
# |Input State = $\begin{pmatrix}0+0j & 1+0j\end{pmatrix}$<br><br>Before measurement,<br>- qubit state = $\begin{pmatrix}0+0j & 0+1j\end{pmatrix}$<br>- qubit has probability 1 of being in state ‘1’<br><br>Post measurement, quit state is ‘1’ with phase pi/2 |![alt](images/L2_Son1_statevector.png) | ![alt](images/L2_Son1_qsphere.png)|![alt](images/L2_Son1_statevector_postmeasurement.png) |

# %% [markdown]
# <h2 style="font-size:24px;">Part 3 - Effect of Single-Qubit Gates on state |+></h2>
#
# <br>
# <div style="background: #E8E7EB; border-radius: 5px;
# -moz-border-radius: 5px;">
#   <p style="background: #800080;
#             border-radius: 5px 5px 0px 0px;
#             padding: 10px 0px 10px 10px;
#             font-size:18px;
#             color:white;
#             "><b>Goal</b></p>
#     <p style=" padding: 0px 0px 10px 10px;
#               font-size:16px;">Create quantum circuits to apply various single qubit gates on state |+> and understand the change in state and phase of the qubit.</p>
# </div>

# %% [markdown]
# |![X gate applied to + state](images/L2_Xon+_circuit.png) | ![Y gate applied to + state](images/L2_Yon+_circuit.png)|![Z gate applied to + state](images/L2_Zon+_circuit.png) | ![S gate applied to + state](images/L2_Son+_circuit.png)|
# |-|-|-|-|
#
# To see the effect of each of the gates, we will take a single circuit with 4 qubits and apply a different gate to each of the qubits to plot the values of each of those qubits on the blocsphere.

# %%
qc3 = QuantumCircuit(4)

# initialize qubits
qc3.h(range(4))

# perform gate operations on individual qubits
qc3.x(0)
qc3.y(1)
qc3.z(2)
qc3.s(3)

# Draw circuit
qc3.draw()

# %%
# Plot blochshere
out3 = execute(qc3,backend).result().get_statevector()
plot_bloch_multivector(out3)

# %% [markdown]
# |Effect on Qubit on application of Gate|Satevector|QSphere Plot|Probability (Histogram)|
# |-|-|-|-|
# |Input State = $\begin{pmatrix}0.707+0j & 0.707+0j\end{pmatrix}$<br><br>Before measurement,<br>- qubit state = $\begin{pmatrix}0.707+0j & 0.707+0j\end{pmatrix}$<br>- qubit has probability 0.5 of being in each of the states ‘0’ and ‘1’ |![alt](images/L2_Xon+_statevector.png) | ![alt](images/L2_Xon+_qsphere.png)|![alt](images/L2_Xon+_histogram.png) |
# |Input State = $\begin{pmatrix}0.707+0j & 0.707+0j\end{pmatrix}$<br><br>Before measurement,<br>- qubit state = $\begin{pmatrix}0-0.707j & 0+0.707j\end{pmatrix}$<br>- qubit has probability 0.5 of being in each of the states ‘0’ and ‘1’ |![alt](images/L2_Yon+_statevector.png) | ![alt](images/L2_Yon+_qsphere.png)|![alt](images/L2_Yon+_histogram.png) |
# |Input State = $\begin{pmatrix}0.707+0j & 0.707+0j\end{pmatrix}$<br><br>Before measurement,<br>- qubit state = $\begin{pmatrix}0.707+0j & -0.707+0j\end{pmatrix}$<br>- qubit has probability 0.5 of being in each of the states ‘0’ and ‘1’ |![alt](images/L2_Zon+_statevector.png) | ![alt](images/L2_Zon+_qsphere.png)|![alt](images/L2_Zon+_histogram.png) |
# |Input State = $\begin{pmatrix}0.707+0j & 0.707+0j\end{pmatrix}$<br><br>Before measurement,<br>- qubit state = $\begin{pmatrix}0.707+0j & 0+0.707j\end{pmatrix}$<br>- qubit has probability 0.5 of being in each of the states ‘0’ and ‘1’ |![alt](images/L2_Son+_statevector.png) | ![alt](images/L2_Son+_qsphere.png)|![alt](images/L2_Son+_histogram.png) |

# %% [markdown]
# <h2 style="font-size:24px;">Part 4 - Effect of Single-Qubit Gates on state |-></h2>
#
# <br>
# <div style="background: #E8E7EB; border-radius: 5px;
# -moz-border-radius: 5px;">
#   <p style="background: #800080;
#             border-radius: 5px 5px 0px 0px;
#             padding: 10px 0px 10px 10px;
#             font-size:18px;
#             color:white;
#             "><b>Goal</b></p>
#     <p style=" padding: 0px 0px 10px 10px;
#               font-size:16px;">Create quantum circuits to apply various single qubit gates on state |-> and understand the change in state and phase of the qubit.</p>
# </div>

# %% [markdown]
# |![X gate applied to - state](images/L2_Xon-_circuit.png) | ![Y gate applied to - state](images/L2_Yon-_circuit.png)|![Z gate applied to - state](images/L2_Zon-_circuit.png) | ![S gate applied to - state](images/L2_Son-_circuit.png)|
# |-|-|-|-|
#
# To see the effect of each of the gates, we will take a single circuit with 4 qubits and apply a different gate to each of the qubits to plot the values of each of those qubits on the blocsphere.

# %%
qc4 = QuantumCircuit(4)

# initialize qubits
qc4.x(range(4))
qc4.h(range(4))

# perform gate operations on individual qubits
qc4.x(0)
qc4.y(1)
qc4.z(2)
qc4.s(3)

# Draw circuit
qc4.draw()

# %%
# Plot blochshere
out4 = execute(qc4,backend).result().get_statevector()
plot_bloch_multivector(out4)

# %% [markdown]
# |Effect on Qubit on application of Gate|Satevector|QSphere Plot|Probability (Histogram)|
# |-|-|-|-|
# |Input State = $\begin{pmatrix}0.707+0j & -0.707+0j\end{pmatrix}$<br><br>Before measurement,<br>- qubit state = $\begin{pmatrix}-0.707+0j & 0.707+0j\end{pmatrix}$<br>- qubit has probability 0.5 of being in each of the states ‘0’ and ‘1’ |![alt](images/L2_Xon-_statevector.png) | ![alt](images/L2_Xon-_qsphere.png)|![alt](images/L2_Xon-_histogram.png) |
# |Input State = $\begin{pmatrix}0.707+0j & -0.707+0j\end{pmatrix}$<br><br>Before measurement,<br>- qubit state = $\begin{pmatrix}0+0.707j & 0+0.707j\end{pmatrix}$<br>- qubit has probability 0.5 of being in each of the states ‘0’ and ‘1’ |![alt](images/L2_Yon-_statevector.png) | ![alt](images/L2_Yon-_qsphere.png)|![alt](images/L2_Yon-_histogram.png) |
# |Input State = $\begin{pmatrix}0.707+0j & -0.707+0j\end{pmatrix}$<br><br>Before measurement,<br>- qubit state = $\begin{pmatrix}0.707+0j & 0.707+0j\end{pmatrix}$<br>- qubit has probability 0.5 of being in each of the states ‘0’ and ‘1’ |![alt](images/L2_Zon-_statevector.png) | ![alt](images/L2_Zon-_qsphere.png)|![alt](images/L2_Zon-_histogram.png) |
# |Input State = $\begin{pmatrix}0.707+0j & -0.707+0j\end{pmatrix}$<br><br>Before measurement,<br>- qubit state = $\begin{pmatrix}0.707+0j & 0-0.707j\end{pmatrix}$<br>- qubit has probability 0.5 of being in each of the states ‘0’ and ‘1’ |![alt](images/L2_Son-_statevector.png) | ![alt](images/L2_Son-_qsphere.png)|![alt](images/L2_Son-_histogram.png) |

# %% [markdown]
# <h2 style="font-size:24px;">Part 5 - Effect of Single-Qubit Gates on state |i></h2>
#
# <br>
# <div style="background: #E8E7EB; border-radius: 5px;
# -moz-border-radius: 5px;">
#   <p style="background: #800080;
#             border-radius: 5px 5px 0px 0px;
#             padding: 10px 0px 10px 10px;
#             font-size:18px;
#             color:white;
#             "><b>Goal</b></p>
#     <p style=" padding: 0px 0px 10px 10px;
#               font-size:16px;">Create quantum circuits to apply various single qubit gates on state |i> and understand the change in state and phase of the qubit.</p>
# </div>

# %% [markdown]
# |![X gate applied to i state](images/L2_Xoni_circuit.png) | ![Y gate applied to i state](images/L2_Yoni_circuit.png)|![Z gate applied to i state](images/L2_Zoni_circuit.png) | ![S gate applied to i state](images/L2_Soni_circuit.png)|
# |-|-|-|-|
#
# To see the effect of each of the gates, we will take a single circuit with 4 qubits and apply a different gate to each of the qubits to plot the values of each of those qubits on the blocsphere.

# %%
qc5 = QuantumCircuit(4)

# initialize qubits
qc5.h(range(4))
qc5.s(range(4))

# perform gate operations on individual qubits
qc5.x(0)
qc5.y(1)
qc5.z(2)
qc5.s(3)

# Draw circuit
qc5.draw()

# %%
# Plot blochshere
out5 = execute(qc5,backend).result().get_statevector()
plot_bloch_multivector(out5)

# %% [markdown]
# |Effect on Qubit on application of Gate|Satevector|QSphere Plot|Probability (Histogram)|
# |-|-|-|-|
# |Input State = $\begin{pmatrix}0.707+0j & 0+0.707j\end{pmatrix}$<br><br>Before measurement,<br>- qubit state = $\begin{pmatrix}0+0.707j & 0.707+0j\end{pmatrix}$<br>- qubit has probability 0.5 of being in each of the states ‘0’ and ‘1’ |![alt](images/L2_Xoni_statevector.png) | ![alt](images/L2_Xoni_qsphere.png)|![alt](images/L2_Xoni_histogram.png) |
# |Input State = $\begin{pmatrix}0.707+0j & 0+0.707j\end{pmatrix}$<br><br>Before measurement,<br>- qubit state = $\begin{pmatrix}0.707+0j & 0+0.707j\end{pmatrix}$<br>- qubit has probability 0.5 of being in each of the states ‘0’ and ‘1’ |![alt](images/L2_Yoni_statevector.png) | ![alt](images/L2_Yoni_qsphere.png)|![alt](images/L2_Yoni_histogram.png) |
# |Input State = $\begin{pmatrix}0.707+0j & 0+0.707j\end{pmatrix}$<br><br>Before measurement,<br>- qubit state = $\begin{pmatrix}0.707+0j & 0-0.707j\end{pmatrix}$<br>- qubit has probability 0.5 of being in each of the states ‘0’ and ‘1’ |![alt](images/L2_Zoni_statevector.png) | ![alt](images/L2_Zoni_qsphere.png)|![alt](images/L2_Zoni_histogram.png) |
# |Input State = $\begin{pmatrix}0.707+0j & 0+0.707j\end{pmatrix}$<br><br>Before measurement,<br>- qubit state = $\begin{pmatrix}0.707+0j & -0.707+0j\end{pmatrix}$<br>- qubit has probability 0.5 of being in each of the states ‘0’ and ‘1’ |![alt](images/L2_Soni_statevector.png) | ![alt](images/L2_Soni_qsphere.png)|![alt](images/L2_Soni_histogram.png) |

# %% [markdown]
# <h2 style="font-size:24px;">Part 6 - Effect of Single-Qubit Gates on state |-i></h2>
#
# <br>
# <div style="background: #E8E7EB; border-radius: 5px;
# -moz-border-radius: 5px;">
#   <p style="background: #800080;
#             border-radius: 5px 5px 0px 0px;
#             padding: 10px 0px 10px 10px;
#             font-size:18px;
#             color:white;
#             "><b>Goal</b></p>
#     <p style=" padding: 0px 0px 10px 10px;
#               font-size:16px;">Create quantum circuits to apply various single qubit gates on state |-i> and understand the change in state and phase of the qubit.</p>
# </div>

# %% [markdown]
# |![X gate applied to -i state](images/L2_Xon-i_circuit.png) | ![Y gate applied to -i state](images/L2_Yon-i_circuit.png) |![Z gate applied to -i state](images/L2_Zon-i_circuit.png) | ![S gate applied to -i state](images/L2_Son-i_circuit.png)|
# |-|-|-|-|
#
# To see the effect of each of the gates, we will take a single circuit with 4 qubits and apply a different gate to each of the qubits to plot the values of each of those qubits on the blocsphere.

# %%
qc6 = QuantumCircuit(4)

# initialize qubits
qc6.x(range(4))
qc6.h(range(4))
qc6.s(range(4))

# perform gate operations on individual qubits
qc6.x(0)
qc6.y(1)
qc6.z(2)
qc6.s(3)

# Draw circuit
qc6.draw()

# %%
# Plot blochshere
out6 = execute(qc6,backend).result().get_statevector()
plot_bloch_multivector(out6)

# %% [markdown]
# |Effect on Qubit on application of Gate|Satevector|QSphere Plot|Probability (Histogram)|
# |-|-|-|-|
# |Input State = $\begin{pmatrix}0.707+0j & 0-0.707j\end{pmatrix}$<br><br>Before measurement,<br>- qubit state = $\begin{pmatrix}0-0.707j & 0.707+0j\end{pmatrix}$<br>- qubit has probability 0.5 of being in each of the states ‘0’ and ‘1’ |![alt](images/L2_Xon-i_statevector.png) | ![alt](images/L2_Xon-i_qsphere.png)|![alt](images/L2_Xon-i_histogram.png) |
# |Input State = $\begin{pmatrix}0.707+0j & 0-0.707j\end{pmatrix}$<br><br>Before measurement,<br>- qubit state = $\begin{pmatrix}-0.707+0j & 0+0.707j\end{pmatrix}$<br>- qubit has probability 0.5 of being in each of the states ‘0’ and ‘1’ |![alt](images/L2_Yon-i_statevector.png) | ![alt](images/L2_Yon-i_qsphere.png)|![alt](images/L2_Yon-i_histogram.png) |
# |Input State = $\begin{pmatrix}0.707+0j & 0-0.707j\end{pmatrix}$<br><br>Before measurement,<br>- qubit state = $\begin{pmatrix}0.707+0j & 0+0.707j\end{pmatrix}$<br>- qubit has probability 0.5 of being in each of the states ‘0’ and ‘1’ |![alt](images/L2_Zon-i_statevector.png) | ![alt](images/L2_Zon-i_qsphere.png)|![alt](images/L2_Zon-i_histogram.png) |
# |Input State = $\begin{pmatrix}0.707+0j & 0-0.707j\end{pmatrix}$<br><br>Before measurement,<br>- qubit state = $\begin{pmatrix}0.707+0j & 0.707+0j\end{pmatrix}$<br>- qubit has probability 0.5 of being in each of the states ‘0’ and ‘1’ |![alt](images/L2_Son-i_statevector.png) | ![alt](images/L2_Son-i_qsphere.png)|![alt](images/L2_Son-i_histogram.png) |

# %%
import qiskit
qiskit.__qiskit_version__
